# %%
import pandas as pd

df = pd.read_csv("../data/monday.csv")

print(df.shape)
# Out:
# (371621, 89)

# %%
df.head()
# Out:
#    Src IP dec  Src Port  Dst IP dec  Dst Port  Protocol Timestamp  \
# 0   134610945         0   134219268         0         0   56:34.2
# 1  3232238089       123  3232238083       123        17   56:55.4
# 2  3232238092      5353  3758096635      5353        17   57:21.1
# 3  3232238092       123  2550302004       123        17   57:31.6
# 4  3232238092       123   760155097       123        17   57:30.6
#
#    Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0      119719148               231                  0
# 1       65511209                 6                  6
# 2      113976922               267                  0
# 3       67037196                 8                  8
# 4       68045057                 8                  8
#
#    Total Length of Fwd Packet  ...  Active Min   Idle Mean      Idle Std  \
# 0                           0  ...          17  12685486.0  5.296658e+06
# 1                         288  ...     1506210  64004884.0  0.000000e+00
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Src IP dec', 'Src Port', 'Dst IP dec', 'Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets', 'Total Length of Fwd Packet', 'Total Length of Bwd Packet', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd RST Flags', 'Bwd RST Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Min', 'Packet Length Max', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'P
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371621 entries, 0 to 371620
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Src IP dec                  371621 non-null  int64
#  1   Src Port                    371621 non-null  int64
#  2   Dst IP dec                  371621 non-null  int64
#  3   Dst Port                    371621 non-null  int64
#  4   Protocol                    371621 non-null  int64
#  5   Timestamp                   371621 non-null  object
#  6   Flow Duration               371621 non-null  int64
#  7   Total Fwd Packet            371621 non-null  int64
#  8   Total Bwd packets           371621 non-null  int64
#  9   Total Length of Fwd Packet  371621 non-null  int64
#  10  Total Length of Bwd Packet  371621 non-null  int64
#  11  Fwd Packet Length Max       371621 non-null  int64
#  12  Fwd Packet Length Min       371621 non-null  int64
# ...

# %%
print(df.isnull().sum())
# Out:
# Src IP dec             0
# Src Port               0
# Dst IP dec             0
# Dst Port               0
# Protocol               0
#                       ..
# ICMP Code              0
# ICMP Type              0
# Total TCP Flow Time    0
# Label                  0
# Attempted Category     0
# Length: 89, dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 4

# %%
df.describe()
# Out:
#          Src IP dec       Src Port    Dst IP dec       Dst Port  \
# count  3.716210e+05  371621.000000  3.716210e+05  371621.000000
# mean   3.230072e+09   50279.279785  2.649527e+09     261.703082
# std    8.081730e+07   16091.947797  9.858171e+08    1934.701945
# min    1.346109e+08       0.000000  1.738141e+07       0.000000
# 25%    3.232238e+09   49556.000000  2.539979e+09      53.000000
# 50%    3.232238e+09   55395.000000  3.232238e+09      53.000000
# 75%    3.232238e+09   60859.000000  3.232238e+09     443.000000
# max    3.568628e+09   65535.000000  4.294967e+09   65490.000000
#
#             Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# count  371621.000000   3.716210e+05     371621.000000      371621.000000
# mean       12.624841   1.484558e+07         14.638758          16.741573
# std         5.393360   3.347401e+07       1065.640971        1401.081489
# min         0.000000   1.000000e+00          0.000000           0.000000
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Src IP dec', 'Src Port', 'Dst IP dec', 'Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets', 'Total Length of Fwd Packet', 'Total Length of Bwd Packet', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd RST Flags', 'Bwd RST Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Min', 'Packet Length Max', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'P
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# BENIGN    371621
# Name: count, dtype: int64

# %%
import pandas as pd

df_tuesday = pd.read_csv("../data/tuesday.csv")

print("Shape:", df_tuesday.shape)
print("\nLabels:")
print(df_tuesday["Label"].value_counts())
# Out:
# Shape: (322078, 89)
#
# Labels:
# Label
# BENIGN                     315106
# FTP-Patator                  3972
# SSH-Patator                  2961
# SSH-Patator - Attempted        27
# FTP-Patator - Attempted        12
# Name: count, dtype: int64

# %%
df_wednesday = pd.read_csv("../data/wednesday.csv")

print("Shape:", df_wednesday.shape)
print("\nLabels:")
print(df_wednesday["Label"].value_counts())
# Out:
# Shape: (496640, 89)
#
# Labels:
# Label
# BENIGN                          319119
# DoS Hulk                        158468
# DoS GoldenEye                     7567
# DoS Slowloris                     3859
# DoS Slowhttptest - Attempted      3368
# DoS Slowloris - Attempted         1847
# DoS Slowhttptest                  1740
# DoS Hulk - Attempted               581
# DoS GoldenEye - Attempted           80
# Heartbleed                          11
# Name: count, dtype: int64

# %%
df_thursday = pd.read_csv("../data/thursday.csv")

print("Shape:", df_thursday.shape)
print("\nLabels:")
print(df_thursday["Label"].value_counts())
# Out:
# Shape: (362075, 89)
#
# Labels:
# Label
# BENIGN                                    288171
# Infiltration - Portscan                    71767
# Web Attack - Brute Force - Attempted        1292
# Web Attack - XSS - Attempted                 655
# Web Attack - Brute Force                      73
# Infiltration - Attempted                      45
# Infiltration                                  36
# Web Attack - XSS                              18
# Web Attack - SQL Injection                    13
# Web Attack - SQL Injection - Attempted         5
# Name: count, dtype: int64

# %%
df_friday = pd.read_csv("../data/friday.csv")

print("Shape:", df_friday.shape)
print("\nLabels:")
print(df_friday["Label"].value_counts())
# Out:
# Shape: (547557, 89)
#
# Labels:
# Label
# BENIGN                288544
# Portscan              159066
# DDoS                   95144
# Botnet - Attempted      4067
# Botnet                   736
# Name: count, dtype: int64

# %%
print("Tuesday:", df_tuesday.shape)
print("Wednesday:", df_wednesday.shape)
print("Thursday:", df_thursday.shape)
print("Friday:", df_friday.shape)
# Out:
# Tuesday: (322078, 89)
# Wednesday: (496640, 89)
# Thursday: (362075, 89)
# Friday: (547557, 89)

# %%
print(df_wednesday.isnull().sum().sum())
# Out:
# 0

# %%
print("Duplicates:", df_wednesday.duplicated().sum())
# Out:
# Duplicates: 6

# %%
print(df_wednesday["Label"].value_counts())
# Out:
# Label
# BENIGN                          319119
# DoS Hulk                        158468
# DoS GoldenEye                     7567
# DoS Slowloris                     3859
# DoS Slowhttptest - Attempted      3368
# DoS Slowloris - Attempted         1847
# DoS Slowhttptest                  1740
# DoS Hulk - Attempted               581
# DoS GoldenEye - Attempted           80
# Heartbleed                          11
# Name: count, dtype: int64

# %%
print(df_wednesday["Label"].value_counts(normalize=True) * 100)
# Out:
# Label
# BENIGN                          64.255598
# DoS Hulk                        31.908022
# DoS GoldenEye                    1.523639
# DoS Slowloris                    0.777022
# DoS Slowhttptest - Attempted     0.678157
# DoS Slowloris - Attempted        0.371899
# DoS Slowhttptest                 0.350354
# DoS Hulk - Attempted             0.116986
# DoS GoldenEye - Attempted        0.016108
# Heartbleed                       0.002215
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df_wednesday["Label"].value_counts().plot(kind="bar")

plt.title("Wednesday Traffic Distribution")
plt.xlabel("Traffic Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.show()

# %%
print("Thursday labels:")
print(df_thursday["Label"].value_counts())
# Out:
# Thursday labels:
# Label
# BENIGN                                    288171
# Infiltration - Portscan                    71767
# Web Attack - Brute Force - Attempted        1292
# Web Attack - XSS - Attempted                 655
# Web Attack - Brute Force                      73
# Infiltration - Attempted                      45
# Infiltration                                  36
# Web Attack - XSS                              18
# Web Attack - SQL Injection                    13
# Web Attack - SQL Injection - Attempted         5
# Name: count, dtype: int64

# %%
print(df_thursday["Label"].value_counts())
# Out:
# Label
# BENIGN                                    288171
# Infiltration - Portscan                    71767
# Web Attack - Brute Force - Attempted        1292
# Web Attack - XSS - Attempted                 655
# Web Attack - Brute Force                      73
# Infiltration - Attempted                      45
# Infiltration                                  36
# Web Attack - XSS                              18
# Web Attack - SQL Injection                    13
# Web Attack - SQL Injection - Attempted         5
# Name: count, dtype: int64

# %%
print(df_thursday["Label"].value_counts())
# Out:
# Label
# BENIGN                                    288171
# Infiltration - Portscan                    71767
# Web Attack - Brute Force - Attempted        1292
# Web Attack - XSS - Attempted                 655
# Web Attack - Brute Force                      73
# Infiltration - Attempted                      45
# Infiltration                                  36
# Web Attack - XSS                              18
# Web Attack - SQL Injection                    13
# Web Attack - SQL Injection - Attempted         5
# Name: count, dtype: int64

# %%
print("Dataset Shape:", df_wednesday.shape)

print("\nNumber of Columns:", len(df_wednesday.columns))

print("\nColumn Names:")
print(df_wednesday.columns.tolist())
# Out:
# Dataset Shape: (496640, 89)
#
# Number of Columns: 89
#
# Column Names:
# ...

# %%
print(df_wednesday.dtypes)
# Out:
# Src IP dec              int64
# Src Port                int64
# Dst IP dec              int64
# Dst Port                int64
# Protocol                int64
#                         ...
# ICMP Code               int64
# ICMP Type               int64
# Total TCP Flow Time     int64
# Label                  object
# Attempted Category      int64
# Length: 89, dtype: object

# %%
missing_values = df_wednesday.isnull().sum()

print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
print("Duplicate rows:", df_wednesday.duplicated().sum())
# Out:
# Duplicate rows: 6

# %%
import matplotlib.pyplot as plt

df_wednesday["Label"].value_counts().plot(kind="bar")

plt.title("Wednesday Traffic Distribution")
plt.xlabel("Traffic Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
label_percentage = df_wednesday["Label"].value_counts(normalize=True) * 100

print(label_percentage)
# Out:
# Label
# BENIGN                          64.255598
# DoS Hulk                        31.908022
# DoS GoldenEye                    1.523639
# DoS Slowloris                    0.777022
# DoS Slowhttptest - Attempted     0.678157
# DoS Slowloris - Attempted        0.371899
# DoS Slowhttptest                 0.350354
# DoS Hulk - Attempted             0.116986
# DoS GoldenEye - Attempted        0.016108
# Heartbleed                       0.002215
# Name: proportion, dtype: float64

# %%
print("Monday:", df.shape)
print("Tuesday:", df_tuesday.shape)
print("Wednesday:", df_wednesday.shape)
print("Thursday:", df_thursday.shape)
print("Friday:", df_friday.shape)
# Out:
# Monday: (371621, 89)
# Tuesday: (322078, 89)
# Wednesday: (496640, 89)
# Thursday: (362075, 89)
# Friday: (547557, 89)

# %%
print("Total missing values:",
      df_wednesday.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Total duplicate rows:",
      df_wednesday.duplicated().sum())
# Out:
# Total duplicate rows: 6

# %%
print(df_wednesday.dtypes)
# Out:
# Src IP dec              int64
# Src Port                int64
# Dst IP dec              int64
# Dst Port                int64
# Protocol                int64
#                         ...
# ICMP Code               int64
# ICMP Type               int64
# Total TCP Flow Time     int64
# Label                  object
# Attempted Category      int64
# Length: 89, dtype: object

# %%
df_wednesday.describe()
# Out:
#          Src IP dec       Src Port    Dst IP dec       Dst Port  \
# count  4.966400e+05  496640.000000  4.966400e+05  496640.000000
# mean   3.107179e+09   48202.464469  2.939000e+09     210.367729
# std    1.784051e+08   13889.100033  7.397861e+08    1903.128172
# min    1.346109e+08       0.000000  1.885313e+07       0.000000
# 25%    2.886730e+09   41236.000000  3.232238e+09      53.000000
# 50%    3.232238e+09   52096.000000  3.232238e+09      80.000000
# 75%    3.232238e+09   58614.000000  3.232238e+09      80.000000
# max    3.559744e+09   65535.000000  4.294967e+09   65178.000000
#
#             Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# count  496640.000000   4.966400e+05     496640.000000      496640.000000
# mean       10.488809   1.210240e+07         13.214097          14.454698
# std         5.412645   3.078214e+07        882.426050        1162.333891
# min         0.000000   1.000000e+00          0.000000           0.000000
# ...

# %%
import matplotlib.pyplot as plt

df_wednesday["Label"].value_counts().plot(kind="bar")

plt.title("CICIDS2017 Wednesday Traffic Distribution")
plt.xlabel("Traffic Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
label_percentage = (
    df_wednesday["Label"]
    .value_counts(normalize=True) * 100
)

print(label_percentage)
# Out:
# Label
# BENIGN                          64.255598
# DoS Hulk                        31.908022
# DoS GoldenEye                    1.523639
# DoS Slowloris                    0.777022
# DoS Slowhttptest - Attempted     0.678157
# DoS Slowloris - Attempted        0.371899
# DoS Slowhttptest                 0.350354
# DoS Hulk - Attempted             0.116986
# DoS GoldenEye - Attempted        0.016108
# Heartbleed                       0.002215
# Name: proportion, dtype: float64

# %%
label_percentage.plot(kind="pie", autopct="%1.1f%%")

plt.title("Wednesday Traffic Percentage")
plt.ylabel("")
plt.show()

# %%
df_wednesday["Traffic_Type"] = df_wednesday["Label"].apply(
    lambda x: "BENIGN" if x == "BENIGN" else "ATTACK"
)

print(df_wednesday["Traffic_Type"].value_counts())
# Out:
# Traffic_Type
# BENIGN    319119
# ATTACK    177521
# Name: count, dtype: int64

# %%
df_wednesday["Traffic_Type"].value_counts().plot(kind="bar")

plt.title("Benign vs Attack Traffic")
plt.xlabel("Traffic Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
numeric_columns = df_wednesday.select_dtypes(
    include="number"
).columns

print("Number of numerical features:", len(numeric_columns))
print(numeric_columns.tolist())
# Out:
# Number of numerical features: 87
# ...

# %%
features = [
    "Flow Duration",
    "Total Fwd Packet",
    "Total Bwd packets",
    "Flow Bytes/s",
    "Flow Packets/s"
]

print(df_wednesday[features].describe())
# Out:
#        Flow Duration  Total Fwd Packet  Total Bwd packets  Flow Bytes/s  \
# count   4.966400e+05     496640.000000      496640.000000  4.966400e+05
# mean    1.210240e+07         13.214097          14.454698  4.698425e+05
# std     3.078214e+07        882.426050        1162.333891  3.718433e+06
# min     1.000000e+00          0.000000           0.000000  0.000000e+00
# 25%     3.048100e+04          2.000000           2.000000  1.406415e+03
# 50%     1.559870e+05          6.000000           5.000000  1.197900e+04
# 75%     1.271786e+06          9.000000           7.000000  1.424000e+05
# max     1.200000e+08     203943.000000      272354.000000  2.530000e+08
#
#        Flow Packets/s
# count    4.966400e+05
# mean     5.552094e+03
# std      4.061853e+04
# min      2.500432e-02
# 25%      1.024362e+01
# 50%      7.500797e+01
# 75%      1.999552e+02
# max      2.000000e+06

# %%
print(df_wednesday.columns.tolist())
# Out:
# ['Src IP dec', 'Src Port', 'Dst IP dec', 'Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets', 'Total Length of Fwd Packet', 'Total Length of Bwd Packet', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd RST Flags', 'Bwd RST Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Min', 'Packet Length Max', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'P
# ...

# %% [markdown]
# ## EDA Observations
#
# 1. The CICIDS2017 dataset contains network-flow records with 89 columns.
# 2. The Label column identifies benign and malicious network traffic.
# 3. The Wednesday dataset contains several DoS attack categories and Heartbleed.
# 4. The dataset contains both normal and attack traffic.
# 5. The distribution of traffic classes is imbalanced, with some attack categories having significantly fewer records than BENIGN traffic.
# 6. This class imbalance should be considered when developing the anomaly-detection model.

# %%
print(df.dtypes.value_counts())
# Out:
# int64      62
# float64    25
# object      2
# Name: count, dtype: int64

# %%
print(df['Label'].unique())
# Out:
# ['BENIGN']

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 4
